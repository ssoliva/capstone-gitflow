# %% [markdown]
# ## Tweets: Gitflow

# %% [markdown]
# #### Carga de datos

# %% [markdown]
# Se importan las librerías a utilizar:

# %%
import pandas as pd

# %% [markdown]
# Se cargan los datos y se visualizan para eliminar cualquier irregularidad:

# %%
df = pd.read_json("farmers.json", lines=True)
df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %% [markdown]
# Como se puede observar varios de los datos no se encuentran normalizados, pero dada la naturaleza de la tarea solicitada no será necesario normalizarlos.

# %% [markdown]
# #### Parte 1: Los 10 tweets mas retweeted

# %% [markdown]
# Se seleccionan los tweets con la mayor cantidad de retweets:

# %%
df.sort_values("retweetCount", ascending=False)[:10]["content"]
# Out:
# 408128    why aren’t we talking about this?! #FarmersPro...
# 395142    We stand in solidarity with the #FarmersProtes...
# 266196    I still #StandWithFarmers and support their pe...
# 366579    “Paid actors,” huh? Quite the casting director...
# 372793    What in the human rights violations is going o...
# 314192    Happy to share that I’ve donated $10,000 to pr...
# 215034    There has been much social media coverage arou...
# 398011    Farmers feed the world. Fight for them. Protec...
# 325261    Should be talking about this! #FarmersProtest\...
# 163689    To all of my influencer/celeb friends- read up...
# Name: content, dtype: object

# %% [markdown]
# #### Parte 2: Los top 10 usuarios en función de la cantidad de tweets que emitieron

# %% [markdown]
# Ahora se seleccionan los usuarios solicitados. Para esto se extrae el usuario primero:

# %%
df["user"] = df["user"].apply(lambda x: x["username"])
df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %% [markdown]
# Con esto ya se puede obtener lo solicitado:

# %%
df["user"].value_counts()[:10]
# Out:
# harjot_tweeting    7134
# tasveersandhu      2091
# shells_n_petals    1991
# jot__b             1841
# rebelpacifist      1806
# rumsomal           1722
# Iamjazzie96        1502
# Jass_k_G           1460
# DigitalKisanBot    1453
# z_khalique007      1446
# Name: user, dtype: int64

# %% [markdown]
# #### Parte 3: Los top 10 días donde hay más tweets

# %% [markdown]
# Se forma nuevo dataframe sólo con el día, se agrupan por día y se disponen por cantidad:

# %%
df_clean = df["user"]

# %% [markdown]
# #### Parte 4: Los top 10 hashtags más usados

# %% [markdown]
# No se como hacerlo :(
